# %% [markdown]
# ## print

# %%
print("hello world ")
print("mahendra")
# Out:
# hello world
# mahendra

# %%
#end in same line , default = new line
print("hello world",end=" ")
print("mahendra")
# Out:
# hello world mahendra

# %%
#seperate by any symbol , default = space
print("hello","mahendra","nath")
print("hello","mahendra","nath",sep="_")
# Out:
# hello mahendra nath
# hello_mahendra_nath

# %% [markdown]
# # variables

# %%
2+3
# Out:
# 5

# %%
a=5.3
print(type(a)) # to check which datatype the variable is 
#same value of a different variable gives same address
id(a)   # to check the address of the variable
# Out:
# <class 'float'>
# 4450218064

# %%
a=12.2
b=12
a-b # should be 0.2 but gives 0.19
# Out:
# 0.1999999999999993

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # Datatypes

# %%
#address values are different for same string values, but same for some condition
#same address for numeric below 256 value ,different address for numeric above 256 value
a= "this is string"
b= 'this is string'
c= 'this is string'
print(id(a))
print(id(b))
print(id(c))
# Out:
# 4452036080
# 4452039472
# 4452038960
